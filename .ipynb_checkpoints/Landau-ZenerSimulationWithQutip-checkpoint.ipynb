# %%
import numpy as np
import matplotlib.pyplot as plt
import qutip
import seaborn
# %matplotlib inline

# %%
def hs1Delta(t,args):
    """
    Frequency Scanned
    args:[T,Delta0,Detuning,Omega0,noise0,noise1]
    """
    Delta = 1.0 * args[1] * np.tanh(2 *1.6* np.pi * (t/args[0]-0.5))+args[2]+\
            args[4]*np.random.rand(len(t))
    return Delta

def hs1Omega(t,args):
    """
    Rabi Frequency Scanned
    args:[T,Delta0,Detuning,Omega0,noise0,noise1]
    """
    Omega = 1.0 * args[3] / np.cosh(2 *1.6* np.pi * (t/args[0]-0.5))
    return Omega

H=[[(qutip.sigmap()+qutip.sigmam())/2,hs1Omega],[-qutip.sigmap()*qutip.sigmam(),hs1Delta]]
#H=[[(qutip.sigmay())/1,hs1Omega],[-qutip.sigmaz()/2,hs1Delta]]

# %%
##args:[T,Delta0,Detuning,Omega0]
T=0.004
Delta0=4000*2*np.pi
Detuning=0
Omega0=4000*2*np.pi
args=[T,Delta0,Detuning,Omega0]
tlist=np.linspace(0,T,500)
plt.grid(True)
plt.plot(tlist*1000,hs1Delta(tlist,args))
plt.plot(tlist*1000,hs1Omega(tlist,args))

# %%
T=0.004
Delta0=4000.0*2*np.pi
Detuning=0*2*np.pi
Omega0=4000.0*2*np.pi
args=[T,Delta0,Detuning,Omega0]

tlist=np.linspace(0,T,500)
expectoper=[qutip.ket2dm(qutip.basis(2,0)),qutip.ket2dm(qutip.basis(2,1))]
s=qutip.mesolve(H, qutip.basis(2,1), tlist, [], expectoper,args=args)
print(s.expect[0][-1])
fig,ax=plt.subplots(2,1,figsize=(6,5))
ax[0].grid(True)
ax[0].set_ylabel('occupation')
ax[1].set_ylabel('$\Delta$, $\Omega$ (kHz)')
ax[1].set_xlabel('time(ms)')
ax[1].grid(True)
ax[0].plot(tlist*1000,s.expect[0],tlist*1000,s.expect[1])
ax[1].plot(tlist*1000,hs1Delta(tlist,args)/(2*np.pi*1000),tlist*1000,hs1Omega(tlist,args)/(2*1000*np.pi))
# Out:
# 0.999830184231
# [<matplotlib.lines.Line2D at 0x128ba93c8>,
#  <matplotlib.lines.Line2D at 0x128ba9cf8>]

# %%
centerstep=np.linspace(-10*1000*2*np.pi,10*1000*2*np.pi,100)
occlist=[]
for center in centerstep:
    args[2]=center
    occ=qutip.mesolve(H, qutip.basis(2,1), tlist, [], expectoper,args=args).expect[0][-1]
    occlist.append(occ)

plt.grid(True)    
plt.plot(centerstep/(2*1000*np.pi),occlist,'orange')
plt.scatter(centerstep/(2*1000*np.pi),occlist)

# %%
plt.grid(True)    
plt.plot(centerstep/(2*1000*np.pi),occlist,'o')
#plt.scatter(centerstep/(2*1000*np.pi),occlist)

# %%
qutip.sigmap()+\
qutip.sigmam()
# Out:
# Quantum object: dims = [[2], [2]], shape = (2, 2), type = oper, isherm = True
# Qobj data =
# [[ 0.  1.]
#  [ 1.  0.]]

# %%
-qutip.sigmap()*qutip.sigmam()
# Out:
# Quantum object: dims = [[2], [2]], shape = (2, 2), type = oper, isherm = True
# Qobj data =
# [[-1.  0.]
#  [ 0.  0.]]
